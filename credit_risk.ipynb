# %% [markdown]
# # Credit Risk Modelling

# %%
import pandas as pd
from scipy.stats import chi2_contingency
from statsmodels.stats.outliers_influence import variance_inflation_factor
from scipy.stats import f_oneway
from sklearn.preprocessing import StandardScaler,LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,precision_recall_fscore_support

# %% [markdown]
# ### 1. Data Preparation

# %% [markdown]
# Reading Data

# %%
df1 = pd.read_excel('data\case_study1.xlsx')
df2 = pd.read_excel('data\case_study2.xlsx')

# %%
print(df1.shape,df2.shape)
# Out:
# (51336, 26) (51336, 62)

# %% [markdown]
# 1.1 Cleaning Data

# %%
def cols_with_missing_vals(data):
    cols = []
    for col in data.columns:
        if data[col].dtype != 'object':
            missing_vals = data[data[col]==-99999].shape[0]
            if missing_vals:
                print(col,':',missing_vals)
                cols.append(col)
    return cols

def drop_missing_from_cols(data,cols):
    for col in cols:
        data = data[data[col]!=-99999]
    return data

def cols_to_be_removed(data):
    cols = []
    for col in data.columns:
        if data[col].dtype != 'object':
            if data[data[col]==-99999].shape[0] > 10000: # missing vals >20% of samples
                cols.append(col)
    if cols: print('Columns to be removed: ',cols)
    return cols

# %%
# Columns with Null values in df1
df1_missing_cols = cols_with_missing_vals(df1)
# Out:
# Age_Oldest_TL : 40
# Age_Newest_TL : 40

# %%
# Dropping rows with Null values
print('df1 shape: ',df1.shape)
df1 = drop_missing_from_cols(df1,df1_missing_cols)
print('df1 shape after dropping rows:',df1.shape)
cols_with_missing_vals(df1)
# Out:
# df1 shape:  (51336, 26)
# df1 shape after dropping rows: (51296, 26)
# []

# %%
# Columns with Null values in df2
cols_with_missing_vals(df2);
# Out:
# time_since_recent_payment : 4291
# time_since_first_deliquency : 35949
# time_since_recent_deliquency : 35949
# max_delinquency_level : 35949
# max_deliq_6mts : 12890
# max_deliq_12mts : 10832
# tot_enq : 6321
# CC_enq : 6321
# CC_enq_L6m : 6321
# CC_enq_L12m : 6321
# PL_enq : 6321
# PL_enq_L6m : 6321
# PL_enq_L12m : 6321
# time_since_recent_enq : 6321
# enq_L12m : 6321
# enq_L6m : 6321
# enq_L3m : 6321
# pct_currentBal_all_TL : 72
# CC_utilization : 47636
# PL_utilization : 44435
# max_unsec_exposure_inPct : 23178

# %%
# Columns with more than 20% of Null values
df2_cols_to_be_removed = cols_to_be_removed(df2)
# Out:
# Columns to be removed:  ['time_since_first_deliquency', 'time_since_recent_deliquency', 'max_delinquency_level', 'max_deliq_6mts', 'max_deliq_12mts', 'CC_utilization', 'PL_utilization', 'max_unsec_exposure_inPct']

# %%
# Dropping them
print('df2 shape: ',df2.shape)
df2.drop(df2_cols_to_be_removed,axis=1,inplace=True)
print('df2.shape after dropping columns:',df2.shape)
# Out:
# df2 shape:  (51336, 62)
# df2.shape after dropping columns: (51336, 54)

# %%
# Dropping other rows with Null values
df2_missing_cols = cols_with_missing_vals(df2)
df2 = drop_missing_from_cols(df2,df2_missing_cols)
print(df2.shape)
# Out:
# time_since_recent_payment : 4291
# tot_enq : 6321
# CC_enq : 6321
# CC_enq_L6m : 6321
# CC_enq_L12m : 6321
# PL_enq : 6321
# PL_enq_L6m : 6321
# PL_enq_L12m : 6321
# time_since_recent_enq : 6321
# enq_L12m : 6321
# enq_L6m : 6321
# enq_L3m : 6321
# pct_currentBal_all_TL : 72
# (42066, 54)

# %%
cols_with_missing_vals(df2)
# Out:
# []

# %%
df2.isna().sum().sum(),df1.isna().sum().sum()
# Out:
# (0, 0)

# %% [markdown]
# 1.2 Merging Data Frames

# %%
# Checking for common columns
for col in df1:
    if col in df2.columns: print(col)
# Out:
# PROSPECTID

# %%
print(f'df1 shape: {df1.shape} \ndf2 shape: {df2.shape}')
df = pd.merge(df1,df2,how='inner',on='PROSPECTID')
df.drop(['PROSPECTID'],axis=1,inplace=True) # Dropping the 'id' feature
print('df shape: ',df.shape)
# Out:
# df1 shape: (51296, 26)
# df2 shape: (42066, 54)
# df shape:  (42064, 78)

# %% [markdown]
# ### 2. Feature Selection

# %% [markdown]
# 2.1 Chi-squared test for Categorical features

# %%
# Categorical columns
categorical_columns = []
for col in df.columns:
    if df[col].dtype=='object' and col!='Approved_Flag':
        categorical_columns.append(col)
print(categorical_columns)
# Out:
# ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']

# %%
for col in categorical_columns:
    chi2, p_val, _, _ = chi2_contingency(pd.crosstab(df[col],df['Approved_Flag']))
    print(col,'---',p_val)
# Out:
# MARITALSTATUS --- 3.578180861038862e-233
# EDUCATION --- 2.6942265249737532e-30
# GENDER --- 1.907936100186563e-05
# last_prod_enq2 --- 0.0
# first_prod_enq2 --- 7.84997610555419e-287

# %%
# Since all the features have p_value < 0.05
# We accept all categorical features

# %% [markdown]
# 2.2 Checking for Multicollinearity(Variation Inflation Factor) of Numerical features

# %%
numeric_columns = [col for col in df.columns if df[col].dtype != 'object']
print(len(numeric_columns))
# Out:
# 72

# %%
# VIF threshold --> 6

vif_data = df[numeric_columns]
total_cols = len(numeric_columns)
columns_to_be_kept = [] # numerical columns after VIF
column_index = 0

for i in range(total_cols):
    vif_value = variance_inflation_factor(vif_data,column_index);
    if vif_value <= 6:
        columns_to_be_kept.append(numeric_columns[i])
        column_index += 1
    else:
        vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
        df.drop([numeric_columns[i]],axis=1,inplace=True)
# Out:
# c:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# c:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# c:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# c:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# c:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\stats\outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)
# C:\Users\bhara\AppData\Local\Temp\ipykernel_9916\549667116.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vif_data.drop([numeric_columns[i]],axis=1,inplace=True)

# %%
print('Numerical Columns: ',vif_data.shape[1])
print('Total Columns: ',df.shape[1])
# Out:
# Numerical Columns:  39
# Total Columns:  45

# %% [markdown]
# 2.3 ANOVA Test for Numerical Features

# %%
columns_to_be_kept_numerical = []
for col in columns_to_be_kept:
    a = list(df[col])  
    b = list(df['Approved_Flag'])  
    
    group_P1 = [value for value, group in zip(a, b) if group == 'P1']
    group_P2 = [value for value, group in zip(a, b) if group == 'P2']
    group_P3 = [value for value, group in zip(a, b) if group == 'P3']
    group_P4 = [value for value, group in zip(a, b) if group == 'P4']

    f_statistic, p_value = f_oneway(group_P1, group_P2, group_P3, group_P4)

    if p_value <= 0.05:
        columns_to_be_kept_numerical.append(col)
    else:
        df.drop([col],axis=1,inplace=True)

# %%
print('Numerical Columns: ',len(columns_to_be_kept_numerical))
print('Total Columns: ',df.shape[1])
# Out:
# Numerical Columns:  37
# Total Columns:  43

# %% [markdown]
# ### 3. Encoding and Scaling

# %%
categorical_columns
# Out:
# ['MARITALSTATUS', 'EDUCATION', 'GENDER', 'last_prod_enq2', 'first_prod_enq2']

# %%
df['last_prod_enq2'].unique()
# Out:
# array(['PL', 'ConsumerLoan', 'AL', 'CC', 'others', 'HL'], dtype=object)

# %% [markdown]
# 3.1 Label Encoding for 'EDUCATION' feature
#
#   * SSC                :    1
#   * 12TH               :    2
#   * GRADUATE           :    3
#   * UNDER GRADUATE     :    3
#   * POST-GRADUATE      :    4
#   * OTHERS             :    1 Can be uneducated or with no documents. So can be verified by business end
#   * PROFESSIONAL       :    3
#
#  Reverse ordering can also be done as long as order is maintained

# %%
# df.loc[df['EDUCATION']=='SSC',['EDUCATION']] = 1
# df.loc[df['EDUCATION']=='12TH',['EDUCATION']] = 2
# df.loc[df['EDUCATION']=='GRADUATE',['EDUCATION']] = 3
# df.loc[df['EDUCATION']=='UNDER GRADUATE',['EDUCATION']] = 3
# df.loc[df['EDUCATION']=='POST-GRADUATE',['EDUCATION']] = 4
# df.loc[df['EDUCATION']=='OTHERS',['EDUCATION']] = 1
# df.loc[df['EDUCATION']=='PROFESSIONAL',['EDUCATION']] = 3

education = {
    'SSC'            : 1,
    '12TH'           : 2,
    'GRADUATE'       : 3,
    'UNDER GRADUATE' : 3,
    'POST-GRADUATE'  : 4,
    'OTHERS'         : 1,
    'PROFESSIONAL'   : 3
}
df['EDUCATION'] = df['EDUCATION'].map(education).astype(int)

# %%
df['EDUCATION'].value_counts()
# Out:
# EDUCATION
# 3    18931
# 2    11703
# 1     9532
# 4     1898
# Name: count, dtype: int64

# %% [markdown]
# 3.2 One Hot Encoding for other categorical columns

# %%
df_encoded = pd.get_dummies(df,columns=['MARITALSTATUS','GENDER','last_prod_enq2','first_prod_enq2'])
df_encoded.shape
# Out:
# (42064, 55)

# %%
df_encoded.describe()
# Out:
#        pct_tl_open_L6M  pct_tl_closed_L6M  Tot_TL_closed_L12M  \
# count     42064.000000       42064.000000        42064.000000
# mean          0.179032           0.097783            0.825504
# std           0.278043           0.210957            1.537208
# min           0.000000           0.000000            0.000000
# 25%           0.000000           0.000000            0.000000
# 50%           0.000000           0.000000            0.000000
# 75%           0.333000           0.100000            1.000000
# max           1.000000           1.000000           33.000000
#
#        pct_tl_closed_L12M  Tot_Missed_Pmnt         CC_TL       Home_TL  \
# count        42064.000000     42064.000000  42064.000000  42064.000000
# mean             0.160365         0.525746      0.145921      0.076241
# std              0.258831         1.106442      0.549314      0.358582
# min              0.000000         0.000000      0.000000      0.000000
# 25%              0.000000         0.000000      0.000000      0.000000
# 50%              0.000000         0.000000      0.000000      0.000000
# 75%              0.250000         1.000000      0.000000      0.000000
# max              1.000000        34.000000     27.000000     10.000000
#
#               PL_TL    Secured_TL  Unsecured_TL  ...       enq_L3m  \
# count  42064.000000  42064.000000  42064.000000  ...  42064.000000
# mean       0.328000      2.921334      2.341646  ...      1.230458
# std        0.916368      6.379764      3.405397  ...      2.069461
# min        0.000000      0.000000      0.000000  ...      0.000000
# 25%        0.000000      0.000000      0.000000  ...      0.000000
# 50%        0.000000      1.000000      1.000000  ...      1.000000
# 75%        0.000000      3.000000      3.000000  ...      2.000000
# max       29.000000    235.000000     55.000000  ...     42.000000
#
#           EDUCATION  NETMONTHLYINCOME  Time_With_Curr_Empr       CC_Flag  \
# count  42064.000000      4.206400e+04         42064.000000  42064.000000
# mean       2.313689      2.692990e+04           110.345783      0.102962
# std        0.871070      2.084300e+04            75.629967      0.303913
# min        1.000000      0.000000e+00             0.000000      0.000000
# 25%        2.000000      1.800000e+04            61.000000      0.000000
# 50%        2.000000      2.400000e+04            92.000000      0.000000
# 75%        3.000000      3.100000e+04           131.000000      0.000000
# max        4.000000      2.500000e+06          1020.000000      1.000000
#
#             PL_Flag  pct_PL_enq_L6m_of_ever  pct_CC_enq_L6m_of_ever  \
# count  42064.000000            42064.000000            42064.000000
# mean       0.193063                0.195497                0.064186
# std        0.394707                0.367414                0.225989
# min        0.000000                0.000000                0.000000
# 25%        0.000000                0.000000                0.000000
# 50%        0.000000                0.000000                0.000000
# 75%        0.000000                0.000000                0.000000
# max        1.000000                1.000000                1.000000
#
#             HL_Flag       GL_Flag
# count  42064.000000  42064.000000
# mean       0.252235      0.056580
# std        0.434300      0.231042
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        1.000000      0.000000
# max        1.000000      1.000000
#
# [8 rows x 38 columns]

# %% [markdown]
# 3.3 Standard Scaling

# %%
scalers = {}
columns_to_be_scaled = ['Age_Oldest_TL', 'Age_Newest_TL', 'time_since_recent_payment', 
                        'max_recent_level_of_deliq', 'recent_level_of_deliq', 
                        'time_since_recent_enq', 'NETMONTHLYINCOME', 'Time_With_Curr_Empr']
for col in columns_to_be_scaled:
    scaler = StandardScaler()
    df_encoded[col] = scaler.fit_transform(df_encoded[col].values.reshape(-1,1))
    scalers[col] = scaler

# %% [markdown]
# ### 4. Modelling

# %% [markdown]
# Data Splitting

# %%
y = df_encoded['Approved_Flag']
x = df_encoded.drop(['Approved_Flag'],axis=1)

x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
print(x_train.shape[0],x_test.shape[0])
# Out:
# 33651 8413

# %%
import xgboost as xgb
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import ExtraTreesClassifier

# %%
models = {
    'DecisionTree': DecisionTreeClassifier(max_depth=20,min_samples_split=10,random_state=42),
    'RandomForest': RandomForestClassifier(n_estimators=200,random_state=42),
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "SVM": SVC(probability=True, random_state=42),
    "KNN": KNeighborsClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42),
    "Naive Bayes": GaussianNB(),
    "AdaBoost": AdaBoostClassifier(random_state=42),
    "Extra Trees": ExtraTreesClassifier(n_estimators=200, random_state=42)
}

# %%
for model_name, model in models.items():
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    accuracy = accuracy_score(y_test, y_pred)
    precision, recall, f1_score, _ = precision_recall_fscore_support(y_test, y_pred, labels=['P1', 'P2', 'P3', 'P4'])

    print(f'Model: {model_name}')
    print(f'Accuracy: {accuracy}')
    for u, v in enumerate(['P1', 'P2', 'P3', 'P4']):
        print(f'Class {v}')
        print(f'Precision: {precision[u]}')
        print(f'Recall: {recall[u]}')
        print(f'F1 Score: {f1_score[u]}')
    print()
# Out:
# Model: DecisionTree
# Accuracy: 0.7125876619517414
# Class P1
# Precision: 0.7254901960784313
# Recall: 0.7297830374753451
# F1 Score: 0.727630285152409
# Class P2
# Precision: 0.8125609518236786
# Recall: 0.8257680872150645
# F1 Score: 0.8191112858828156
# Class P3
# Precision: 0.3494837172359015
# Recall: 0.3320754716981132
# F1 Score: 0.34055727554179566
# Class P4
# Precision: 0.6444885799404171
# Recall: 0.630709426627794
# F1 Score: 0.637524557956778
#
# Model: RandomForest
# Accuracy: 0.7665517651254011
# Class P1
# Precision: 0.8433014354066986
# Recall: 0.6952662721893491
# F1 Score: 0.7621621621621621
# Class P2
# Precision: 0.7952356817029904
# Recall: 0.9330029732408325
# F1 Score: 0.8586282378693907
# Class P3
# Precision: 0.4608
# Recall: 0.21735849056603773
# F1 Score: 0.2953846153846154
# Class P4
# Precision: 0.7250726040658277
# Recall: 0.7278911564625851
# F1 Score: 0.7264791464597479
#
# Model: Logistic Regression
# Accuracy: 0.749435397598954
# Class P1
# Precision: 0.8329466357308585
# Recall: 0.7080867850098619
# F1 Score: 0.7654584221748401
# Class P2
# Precision: 0.7686821202788134
# Recall: 0.9399405351833499
# F1 Score: 0.8457285535937221
# Class P3
# Precision: 0.4055727554179567
# Recall: 0.09886792452830188
# F1 Score: 0.15898058252427186
# Class P4
# Precision: 0.6742209631728046
# Recall: 0.6938775510204082
# F1 Score: 0.6839080459770115
#
# Model: SVM
# Accuracy: 0.7541899441340782
# Class P1
# Precision: 0.8105975197294251
# Recall: 0.7090729783037475
# F1 Score: 0.7564439768542872
# Class P2
# Precision: 0.7659744408945687
# Recall: 0.9504459861248761
# F1 Score: 0.848297213622291
# Class P3
# Precision: 0.44525547445255476
# Recall: 0.13811320754716983
# F1 Score: 0.2108294930875576
# Class P4
# Precision: 0.7578947368421053
# Recall: 0.6297376093294461
# F1 Score: 0.6878980891719745
#
# Model: KNN
# Accuracy: 0.6960656127421847
# Class P1
# Precision: 0.6897767332549941
# Recall: 0.5788954635108481
# F1 Score: 0.6294906166219839
# Class P2
# Precision: 0.7353326778105539
# Recall: 0.8893954410307235
# F1 Score: 0.8050596573068988
# Class P3
# Precision: 0.3604806408544726
# Recall: 0.2037735849056604
# F1 Score: 0.26036644165863065
# Class P4
# Precision: 0.720112517580872
# Recall: 0.4975704567541302
# F1 Score: 0.5885057471264368
#
# Model: Gradient Boosting
# Accuracy: 0.7771306311660525
# Class P1
# Precision: 0.8384279475982532
# Recall: 0.757396449704142
# F1 Score: 0.7958549222797927
# Class P2
# Precision: 0.808697146785837
# Recall: 0.9326065411298315
# F1 Score: 0.8662432108993833
# Class P3
# Precision: 0.4766619519094767
# Recall: 0.25433962264150944
# F1 Score: 0.3316929133858268
# Class P4
# Precision: 0.7489711934156379
# Recall: 0.7074829931972789
# F1 Score: 0.7276361819090454
#
# Model: Naive Bayes
# Accuracy: 0.48936170212765956
# Class P1
# Precision: 0.5139013452914798
# Recall: 0.5650887573964497
# F1 Score: 0.5382808830436825
# Class P2
# Precision: 0.7569489334195216
# Recall: 0.46422200198216057
# F1 Score: 0.5755006757586927
# Class P3
# Precision: 0.22723543888433143
# Recall: 0.4181132075471698
# F1 Score: 0.2944459208078661
# Class P4
# Precision: 0.3669309173272933
# Recall: 0.6297376093294461
# F1 Score: 0.4636851520572451
# c:\Users\bhara\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\ensemble\_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Model: AdaBoost
# Accuracy: 0.7487222156186853
# Class P1
# Precision: 0.8006012024048096
# Recall: 0.7879684418145957
# F1 Score: 0.794234592445328
# Class P2
# Precision: 0.7719816272965879
# Recall: 0.932804757185332
# F1 Score: 0.8448074679113186
# Class P3
# Precision: 0.21428571428571427
# Recall: 0.0022641509433962265
# F1 Score: 0.004480955937266617
# Class P4
# Precision: 0.6061302681992338
# Recall: 0.7687074829931972
# F1 Score: 0.6778063410454156
#
# Model: Extra Trees
# Accuracy: 0.7355283489837157
# Class P1
# Precision: 0.8386648122392212
# Recall: 0.5946745562130178
# F1 Score: 0.6959030582804385
# Class P2
# Precision: 0.7576632964211202
# Recall: 0.9357779980178395
# F1 Score: 0.8373536715147215
# Class P3
# Precision: 0.4107485604606526
# Recall: 0.16150943396226414
# F1 Score: 0.23185265438786565
# Class P4
# Precision: 0.6900212314225053
# Recall: 0.6316812439261419
# F1 Score: 0.6595636732623034

# %% [markdown]
# 4.1 Random Forest

# %%
random_forest_classifier = RandomForestClassifier(200,random_state=42).fit(x_train,y_train)
y_pred = random_forest_classifier.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy: {accuracy}')
precision,recall,f1_score,_ = precision_recall_fscore_support(y_test,y_pred)

for u,v in enumerate(['p1','p2','p3','p4']):
    print()
    print(f'Class {v}')
    print(f'Precision: {precision[u]}')
    print(f'Recall: {recall[u]}')
    print(f'f1 Score: {f1_score[u]}')
# Out:
# Accuracy: 0.7650065375014858
#
# Class p1
# Precision: 0.8358913813459268
# Recall: 0.6982248520710059
# f1 Score: 0.7608812466415905
#
# Class p2
# Precision: 0.7965698760400747
# Recall: 0.9298315163528246
# f1 Score: 0.8580574355222242
#
# Class p3
# Precision: 0.44976816074188564
# Recall: 0.21962264150943397
# f1 Score: 0.295131845841785
#
# Class p4
# Precision: 0.7242718446601941
# Recall: 0.7249757045675413
# f1 Score: 0.7246236036911122

# %% [markdown]
# 4.2 XGBoost

# %%
xgb_classifier = xgb.XGBClassifier(objective='multi:softmax', num_class=4)
encoder = LabelEncoder()
y_encoded = encoder.fit_transform(y)
x_train, x_test, y_train, y_test = train_test_split(x,y_encoded,test_size=0.2,random_state=42)

xgb_classifier.fit(x_train,y_train)
y_pred = xgb_classifier.predict(x_test)

accuracy = accuracy_score(y_test,y_pred)
print(f'Accuracy: {accuracy}')
precision,recall,f1_score,_ = precision_recall_fscore_support(y_test,y_pred)

for u,v in enumerate(['p1','p2','p3','p4']):
    print()
    print(f'Class {v}')
    print(f'Precision: {precision[u]}')
    print(f'Recall: {recall[u]}')
    print(f'f1 Score: {f1_score[u]}')
# Out:
# Accuracy: 0.7783192677998336
#
# Class p1
# Precision: 0.823906083244397
# Recall: 0.7613412228796844
# f1 Score: 0.7913890312660175
#
# Class p2
# Precision: 0.8255418233924413
# Recall: 0.913577799801784
# f1 Score: 0.8673315769665035
#
# Class p3
# Precision: 0.4756380510440835
# Recall: 0.30943396226415093
# f1 Score: 0.37494284407864653
#
# Class p4
# Precision: 0.7342386032977691
# Recall: 0.7356656948493683
# f1 Score: 0.7349514563106796

# %% [markdown]
# These are 2 of our best models

# %% [markdown]
# ### 5. Hyperparameter Tuning

# %%
param_grid = {
    'colsample_bytree': [0.1, 0.3, 0.5, 0.7, 0.9],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 5, 8, 10],
    'alpha': [1, 10, 100],
    'n_estimators': [50, 100, 200]
}
answers_grid = {
    'combination': [], 'train_accuracy': [], 'test_accuracy': [],
    'colsample_bytree': [], 'learning_rate': [], 'max_depth': [],
    'alpha': [], 'n_estimators': []
}

# %%
combination = 0
x_train, x_test, y_train, y_test = train_test_split(x,y_encoded,test_size=0.2,random_state=42)

for colsample_bytree in param_grid['colsample_bytree']:
    for learning_rate in param_grid['learning_rate']:
        for max_depth in param_grid['max_depth']:
            for alpha in param_grid['alpha']:
                for n_estimators in param_grid['n_estimators']:
                    model = xgb.XGBClassifier(objective='multi:softmax', num_class=4,
                                              colsample_bytree=colsample_bytree,
                                              learning_rate=learning_rate, max_depth=max_depth,
                                              alpha=alpha, n_estimators=n_estimators)
                    model.fit(x_train, y_train)
                    y_pred_train = model.predict(x_train)
                    y_pred_test = model.predict(x_test)
                    train_accuracy = accuracy_score(y_train, y_pred_train)
                    test_accuracy = accuracy_score(y_test, y_pred_test)
                    answers_grid['combination'].append(combination)
                    answers_grid['train_accuracy'].append(train_accuracy)
                    answers_grid['test_accuracy'].append(test_accuracy)
                    answers_grid['colsample_bytree'].append(colsample_bytree)
                    answers_grid['learning_rate'].append(learning_rate)
                    answers_grid['max_depth'].append(max_depth)
                    answers_grid['alpha'].append(alpha)
                    answers_grid['n_estimators'].append(n_estimators)
                    combination += 1

                    print(f'Combination {combination}')
                    print(f'colsample_bytree: {colsample_bytree}, learning_rate: {learning_rate}, max_depth: {max_depth}, alpha: {alpha}, n_estimators: {n_estimators}')
                    print(f'Train Accuracy: {train_accuracy:.2f}')
                    print(f'Test Accuracy: {test_accuracy:.2f}')
                    print('.'*30)
# Out:
# Combination 1
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 2
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 3
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.62
# Test Accuracy: 0.62
# ..............................
# Combination 4
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 5
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 6
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.62
# Test Accuracy: 0.62
# ..............................
# Combination 7
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 8
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 9
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 10
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 11
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 12
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.63
# Test Accuracy: 0.63
# ..............................
# Combination 13
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.61
# ..............................
# Combination 14
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.61
# ..............................
# Combination 15
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.63
# Test Accuracy: 0.62
# ..............................
# Combination 16
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 17
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 18
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 19
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 20
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 21
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.64
# Test Accuracy: 0.63
# ..............................
# Combination 22
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.61
# ..............................
# Combination 23
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 24
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.63
# Test Accuracy: 0.62
# ..............................
# Combination 25
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 26
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 27
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 28
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 29
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.63
# Test Accuracy: 0.61
# ..............................
# Combination 30
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.65
# Test Accuracy: 0.63
# ..............................
# Combination 31
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.61
# ..............................
# Combination 32
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.62
# Test Accuracy: 0.61
# ..............................
# Combination 33
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.63
# Test Accuracy: 0.62
# ..............................
# Combination 34
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 35
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 36
# colsample_bytree: 0.1, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.61
# Test Accuracy: 0.60
# ..............................
# Combination 37
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy: 0.67
# ..............................
# Combination 38
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.71
# ..............................
# Combination 39
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.74
# ..............................
# Combination 40
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.68
# Test Accuracy: 0.67
# ..............................
# Combination 41
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.71
# ..............................
# Combination 42
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 43
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.66
# ..............................
# Combination 44
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 45
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.73
# ..............................
# Combination 46
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy: 0.68
# ..............................
# Combination 47
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy: 0.72
# ..............................
# Combination 48
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.75
# ..............................
# Combination 49
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy: 0.68
# ..............................
# Combination 50
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy: 0.71
# ..............................
# Combination 51
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 52
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.66
# ..............................
# Combination 53
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy: 0.70
# ..............................
# Combination 54
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.73
# ..............................
# Combination 55
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.68
# ..............................
# Combination 56
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.72
# ..............................
# Combination 57
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.83
# Test Accuracy: 0.74
# ..............................
# Combination 58
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy: 0.68
# ..............................
# Combination 59
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy: 0.71
# ..............................
# Combination 60
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 61
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.66
# ..............................
# Combination 62
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy: 0.70
# ..............................
# Combination 63
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 64
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy: 0.68
# ..............................
# Combination 65
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.72
# ..............................
# Combination 66
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.86
# Test Accuracy: 0.74
# ..............................
# Combination 67
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.69
# Test Accuracy: 0.68
# ..............................
# Combination 68
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy: 0.71
# ..............................
# Combination 69
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 70
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.66
# ..............................
# Combination 71
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy: 0.70
# ..............................
# Combination 72
# colsample_bytree: 0.1, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.73
# ..............................
# Combination 73
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 74
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 75
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.76
# ..............................
# Combination 76
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy: 0.72
# ..............................
# Combination 77
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 78
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 79
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 80
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy: 0.73
# ..............................
# Combination 81
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.75
# Test Accuracy: 0.75
# ..............................
# Combination 82
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.73
# ..............................
# Combination 83
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.75
# ..............................
# Combination 84
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.81
# Test Accuracy: 0.76
# ..............................
# Combination 85
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.72
# ..............................
# Combination 86
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 87
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.76
# ..............................
# Combination 88
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 89
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 90
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 91
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.73
# ..............................
# Combination 92
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy: 0.74
# ..............................
# Combination 93
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.88
# Test Accuracy: 0.75
# ..............................
# Combination 94
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.72
# ..............................
# Combination 95
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 96
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.76
# ..............................
# Combination 97
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 98
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 99
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 100
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy: 0.72
# ..............................
# Combination 101
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy: 0.74
# ..............................
# Combination 102
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.92
# Test Accuracy: 0.75
# ..............................
# Combination 103
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.72
# ..............................
# Combination 104
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 105
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.76
# ..............................
# Combination 106
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 107
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 108
# colsample_bytree: 0.1, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 109
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.67
# ..............................
# Combination 110
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy: 0.68
# ..............................
# Combination 111
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.70
# Test Accuracy: 0.70
# ..............................
# Combination 112
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.67
# ..............................
# Combination 113
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy: 0.68
# ..............................
# Combination 114
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 115
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.66
# ..............................
# Combination 116
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.67
# Test Accuracy: 0.66
# ..............................
# Combination 117
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.69
# Test Accuracy: 0.68
# ..............................
# Combination 118
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 119
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 120
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 121
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 122
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 123
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.71
# ..............................
# Combination 124
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.67
# ..............................
# Combination 125
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy: 0.67
# ..............................
# Combination 126
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 127
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy: 0.71
# ..............................
# Combination 128
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.74
# Test Accuracy: 0.71
# ..............................
# Combination 129
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.73
# ..............................
# Combination 130
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 131
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.70
# ..............................
# Combination 132
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.74
# Test Accuracy: 0.72
# ..............................
# Combination 133
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.67
# ..............................
# Combination 134
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy: 0.67
# ..............................
# Combination 135
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 136
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy: 0.71
# ..............................
# Combination 137
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.71
# ..............................
# Combination 138
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.73
# ..............................
# Combination 139
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy: 0.70
# ..............................
# Combination 140
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.70
# ..............................
# Combination 141
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.75
# Test Accuracy: 0.72
# ..............................
# Combination 142
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.67
# Test Accuracy: 0.67
# ..............................
# Combination 143
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.68
# Test Accuracy: 0.67
# ..............................
# Combination 144
# colsample_bytree: 0.3, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 145
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 146
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 147
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 148
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 149
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 150
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 151
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 152
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.75
# ..............................
# Combination 153
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 154
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.76
# ..............................
# Combination 155
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 156
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.82
# Test Accuracy: 0.78
# ..............................
# Combination 157
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 158
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 159
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 160
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 161
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 162
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 163
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy: 0.76
# ..............................
# Combination 164
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy: 0.77
# ..............................
# Combination 165
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.91
# Test Accuracy: 0.78
# ..............................
# Combination 166
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.76
# ..............................
# Combination 167
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 168
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.83
# Test Accuracy: 0.78
# ..............................
# Combination 169
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 170
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 171
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 172
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.87
# Test Accuracy: 0.76
# ..............................
# Combination 173
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.92
# Test Accuracy: 0.77
# ..............................
# Combination 174
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.97
# Test Accuracy: 0.77
# ..............................
# Combination 175
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.76
# ..............................
# Combination 176
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy: 0.77
# ..............................
# Combination 177
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.84
# Test Accuracy: 0.78
# ..............................
# Combination 178
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 179
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 180
# colsample_bytree: 0.3, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 181
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 182
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 183
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 184
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 185
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 186
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 187
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.75
# ..............................
# Combination 188
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 189
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 190
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 191
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy: 0.78
# ..............................
# Combination 192
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.85
# Test Accuracy: 0.78
# ..............................
# Combination 193
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 194
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 195
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.82
# Test Accuracy: 0.78
# ..............................
# Combination 196
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 197
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 198
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 199
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.86
# Test Accuracy: 0.77
# ..............................
# Combination 200
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.91
# Test Accuracy: 0.77
# ..............................
# Combination 201
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.96
# Test Accuracy: 0.77
# ..............................
# Combination 202
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy: 0.77
# ..............................
# Combination 203
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy: 0.77
# ..............................
# Combination 204
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.86
# Test Accuracy: 0.77
# ..............................
# Combination 205
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 206
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.76
# ..............................
# Combination 207
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 208
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.92
# Test Accuracy: 0.77
# ..............................
# Combination 209
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.96
# Test Accuracy: 0.77
# ..............................
# Combination 210
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.99
# Test Accuracy: 0.77
# ..............................
# Combination 211
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy: 0.77
# ..............................
# Combination 212
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.84
# Test Accuracy: 0.78
# ..............................
# Combination 213
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.88
# Test Accuracy: 0.78
# ..............................
# Combination 214
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 215
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 216
# colsample_bytree: 0.3, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 217
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.71
# ..............................
# Combination 218
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.71
# ..............................
# Combination 219
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.73
# ..............................
# Combination 220
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.71
# Test Accuracy: 0.71
# ..............................
# Combination 221
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.71
# ..............................
# Combination 222
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.73
# Test Accuracy: 0.73
# ..............................
# Combination 223
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.70
# Test Accuracy: 0.69
# ..............................
# Combination 224
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.71
# Test Accuracy: 0.70
# ..............................
# Combination 225
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.72
# Test Accuracy: 0.72
# ..............................
# Combination 226
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 227
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 228
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 229
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 230
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 231
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 232
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.72
# Test Accuracy: 0.71
# ..............................
# Combination 233
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.72
# Test Accuracy: 0.72
# ..............................
# Combination 234
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 235
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.76
# ..............................
# Combination 236
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.76
# ..............................
# Combination 237
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.81
# Test Accuracy: 0.76
# ..............................
# Combination 238
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 239
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.75
# ..............................
# Combination 240
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.76
# ..............................
# Combination 241
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 242
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 243
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 244
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy: 0.76
# ..............................
# Combination 245
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy: 0.76
# ..............................
# Combination 246
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.85
# Test Accuracy: 0.77
# ..............................
# Combination 247
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.75
# ..............................
# Combination 248
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.75
# ..............................
# Combination 249
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.76
# ..............................
# Combination 250
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 251
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.73
# Test Accuracy: 0.72
# ..............................
# Combination 252
# colsample_bytree: 0.5, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 253
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 254
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 255
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 256
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 257
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 258
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 259
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 260
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.76
# Test Accuracy: 0.76
# ..............................
# Combination 261
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 262
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 263
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 264
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.83
# Test Accuracy: 0.78
# ..............................
# Combination 265
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 266
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 267
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 268
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 269
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 270
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 271
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.84
# Test Accuracy: 0.77
# ..............................
# Combination 272
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.87
# Test Accuracy: 0.78
# ..............................
# Combination 273
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.92
# Test Accuracy: 0.78
# ..............................
# Combination 274
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 275
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.82
# Test Accuracy: 0.78
# ..............................
# Combination 276
# colsample_bytree: 0.5, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.84
# Test Accuracy: 0.78
# ..............................
# ...
# Train Accuracy: 0.74
# Test Accuracy: 0.73
# ..............................
# Combination 450
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.75
# Test Accuracy: 0.75
# ..............................
# Combination 451
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 452
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy: 0.77
# ..............................
# Combination 453
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.82
# Test Accuracy: 0.77
# ..............................
# Combination 454
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.76
# ..............................
# Combination 455
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 456
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 457
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 458
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 459
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 460
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.83
# Test Accuracy: 0.77
# ..............................
# Combination 461
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.84
# Test Accuracy: 0.77
# ..............................
# Combination 462
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.86
# Test Accuracy: 0.77
# ..............................
# Combination 463
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy: 0.76
# ..............................
# Combination 464
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 465
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.77
# ..............................
# Combination 466
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.74
# ..............................
# Combination 467
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.75
# Test Accuracy: 0.75
# ..............................
# Combination 468
# colsample_bytree: 0.9, learning_rate: 0.01, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.76
# Test Accuracy: 0.75
# ..............................
# Combination 469
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy: 0.76
# ..............................
# Combination 470
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 471
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 472
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.76
# Test Accuracy: 0.76
# ..............................
# Combination 473
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 474
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 475
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.75
# Test Accuracy: 0.75
# ..............................
# Combination 476
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 477
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 478
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 479
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 480
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.83
# Test Accuracy: 0.78
# ..............................
# Combination 481
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.79
# Test Accuracy: 0.77
# ..............................
# Combination 482
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 483
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 484
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.76
# ..............................
# Combination 485
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 486
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 487
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.84
# Test Accuracy: 0.78
# ..............................
# Combination 488
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.88
# Test Accuracy: 0.78
# ..............................
# Combination 489
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.94
# Test Accuracy: 0.78
# ..............................
# Combination 490
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 491
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy: 0.78
# ..............................
# Combination 492
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.86
# Test Accuracy: 0.78
# ..............................
# Combination 493
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 494
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 495
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 496
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.90
# Test Accuracy: 0.77
# ..............................
# Combination 497
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.94
# Test Accuracy: 0.77
# ..............................
# Combination 498
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 0.99
# Test Accuracy: 0.77
# ..............................
# Combination 499
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.82
# Test Accuracy: 0.78
# ..............................
# Combination 500
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.85
# Test Accuracy: 0.78
# ..............................
# Combination 501
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.89
# Test Accuracy: 0.78
# ..............................
# Combination 502
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 503
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 504
# colsample_bytree: 0.9, learning_rate: 0.1, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 505
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 506
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 507
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 1, n_estimators: 200
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 508
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 509
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 510
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 10, n_estimators: 200
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 511
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 50
# Train Accuracy: 0.77
# Test Accuracy: 0.77
# ..............................
# Combination 512
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 513
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 3, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 514
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 50
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 515
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 100
# Train Accuracy: 0.83
# Test Accuracy: 0.78
# ..............................
# Combination 516
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 1, n_estimators: 200
# Train Accuracy: 0.87
# Test Accuracy: 0.78
# ..............................
# Combination 517
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 50
# Train Accuracy: 0.80
# Test Accuracy: 0.78
# ..............................
# Combination 518
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 100
# Train Accuracy: 0.81
# Test Accuracy: 0.78
# ..............................
# Combination 519
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 10, n_estimators: 200
# Train Accuracy: 0.83
# Test Accuracy: 0.77
# ..............................
# Combination 520
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 521
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 100
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 522
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 5, alpha: 100, n_estimators: 200
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 523
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 50
# Train Accuracy: 0.88
# Test Accuracy: 0.78
# ..............................
# Combination 524
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 100
# Train Accuracy: 0.94
# Test Accuracy: 0.77
# ..............................
# Combination 525
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 1, n_estimators: 200
# Train Accuracy: 0.99
# Test Accuracy: 0.77
# ..............................
# Combination 526
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 50
# Train Accuracy: 0.83
# Test Accuracy: 0.78
# ..............................
# Combination 527
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 100
# Train Accuracy: 0.86
# Test Accuracy: 0.78
# ..............................
# Combination 528
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 10, n_estimators: 200
# Train Accuracy: 0.90
# Test Accuracy: 0.77
# ..............................
# Combination 529
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 530
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 531
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 8, alpha: 100, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 532
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 50
# Train Accuracy: 0.94
# Test Accuracy: 0.78
# ..............................
# Combination 533
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 100
# Train Accuracy: 0.99
# Test Accuracy: 0.77
# ..............................
# Combination 534
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 1, n_estimators: 200
# Train Accuracy: 1.00
# Test Accuracy: 0.77
# ..............................
# Combination 535
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 50
# Train Accuracy: 0.85
# Test Accuracy: 0.78
# ..............................
# Combination 536
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 100
# Train Accuracy: 0.89
# Test Accuracy: 0.78
# ..............................
# Combination 537
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 10, n_estimators: 200
# Train Accuracy: 0.93
# Test Accuracy: 0.77
# ..............................
# Combination 538
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 50
# Train Accuracy: 0.78
# Test Accuracy: 0.77
# ..............................
# Combination 539
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 100
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................
# Combination 540
# colsample_bytree: 0.9, learning_rate: 0.2, max_depth: 10, alpha: 100, n_estimators: 200
# Train Accuracy: 0.79
# Test Accuracy: 0.78
# ..............................

# %%
results = pd.DataFrame(answers_grid)
results.to_excel('tuning_results.xlsx',index=False)
results.head()
# Out:
#    combination  train_accuracy  test_accuracy  colsample_bytree  \
# 0            0        0.611156       0.603471               0.1
# 1            1        0.611839       0.604184               0.1
# 2            2        0.623072       0.617497               0.1
# 3            3        0.610383       0.602995               0.1
# 4            4        0.610829       0.603471               0.1
#
#    learning_rate  max_depth  alpha  n_estimators
# 0           0.01          3      1            50
# 1           0.01          3      1           100
# 2           0.01          3      1           200
# 3           0.01          3     10            50
# 4           0.01          3     10           100

# %% [markdown]
# ### 6. Training best model from Tuning results

# %%
model = xgb.XGBClassifier(objective='multi:softmax', num_class=4,
                          colsample_bytree=0.5, learning_rate=0.2,
                          max_depth=3, alpha=10, n_estimators=200)
model.fit(x_train,y_train)
# Out:
# XGBClassifier(alpha=10, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.2, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=None, num_class=4, ...)

# %% [markdown]
# ### 7. Predicting On Unseen Data

# %%
columns = list(df.columns)
columns.pop()
# Out:
# 'Approved_Flag'

# %%
df3 = pd.read_excel(r'data\Unseen_Dataset.xlsx')
df_unseen = df3[columns]
df_unseen['EDUCATION'] = df_unseen['EDUCATION'].map(education).astype('int')
df_unseen = pd.get_dummies(df_unseen,columns=['MARITALSTATUS','GENDER','last_prod_enq2','first_prod_enq2'])
for col in columns_to_be_scaled:
    df_unseen[col] = scalers[col].transform(df_unseen[col].values.reshape(-1,1))

y_pred_unseen = model.predict(df_unseen)
df3['Target_variable'] = LabelEncoder().fit(y).inverse_transform(y_pred_unseen)
df3.to_excel(r'final_predictions.xlsx',index=False)
